# %%
import pandas as pd

# %%
notas = pd.read_csv('/content/ratings.csv')

# %%
notas['rating'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
notas
# Out:
#         userId   movieId  rating     timestamp
# 0            1       1.0     4.0  9.649827e+08
# 1            1       3.0     4.0  9.649812e+08
# 2            1       6.0     4.0  9.649822e+08
# 3            1      47.0     5.0  9.649838e+08
# 4            1      50.0     5.0  9.649829e+08
# ...        ...       ...     ...           ...
# 112821     610  166534.0     4.0  1.493848e+09
# 112822     610  168248.0     5.0  1.493850e+09
# 112823     610  168250.0     5.0  1.494273e+09
# 112824     610  168252.0     5.0  1.493846e+09
# 112825     610  170875.0     3.0  1.493846e+09
#
# [112826 rows x 4 columns]

# %%
notas.columns = ['usuarioId', 'filmeId', 'nota', 'momento']

# %%
notas
# Out:
#         usuarioId  filmesId  nota       momento
# 0               1       1.0   4.0  9.649827e+08
# 1               1       3.0   4.0  9.649812e+08
# 2               1       6.0   4.0  9.649822e+08
# 3               1      47.0   5.0  9.649838e+08
# 4               1      50.0   5.0  9.649829e+08
# ...           ...       ...   ...           ...
# 112821        610  166534.0   4.0  1.493848e+09
# 112822        610  168248.0   5.0  1.493850e+09
# 112823        610  168250.0   5.0  1.494273e+09
# 112824        610  168252.0   5.0  1.493846e+09
# 112825        610  170875.0   3.0  1.493846e+09
#
# [112826 rows x 4 columns]

# %%
notas['nota'].median()
# Out:
# 3.5

# %%
mediana = notas['nota'].median()
media = notas['nota'].mean()
print(f'Mediana e {mediana}')
print(f'Media e {media}')
# Out:
# Mediana e 3.5
# Media e 3.487569244405052

# %%
notas['nota'].describe()
# Out:
# count    112825.000000
# mean          3.487569
# std           1.042921
# min           0.500000
# 25%           3.000000
# 50%           3.500000
# 75%           4.000000
# max           5.000000
# Name: nota, dtype: float64

# %%
import seaborn as sns
sns.boxplot(notas['nota'])
# Out:
# <Axes: ylabel='nota'>

# %%
filmes = pd.read_csv('/content/movies.csv')
filmes.columns = ['filmesId', 'titulo', 'genero']
filmes.head()
# Out:
#    filmesId                              titulo  \
# 0         1                    Toy Story (1995)
# 1         2                      Jumanji (1995)
# 2         3             Grumpier Old Men (1995)
# 3         4            Waiting to Exhale (1995)
# 4         5  Father of the Bride Part II (1995)
#
#                                         genero
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
notas.head()
# Out:
#    usuarioId  filmesId  nota      momento
# 0          1       1.0   4.0  964982703.0
# 1          1       3.0   4.0  964981247.0
# 2          1       6.0   4.0  964982224.0
# 3          1      47.0   5.0  964983815.0
# 4          1      50.0   5.0  964982931.0

# %%
notas.query('filmeId==1')
# Out:
#         usuarioId  filmeId  nota       momento
# 0               1      1.0   4.0  9.649827e+08
# 516             5      1.0   4.0  8.474350e+08
# 874             7      1.0   4.5  1.106636e+09
# 1434           15      1.0   2.5  1.510578e+09
# 1667           17      1.0   4.5  1.305696e+09
# ...           ...      ...   ...           ...
# 109354        606      1.0   2.5  1.349083e+09
# 110469        607      1.0   4.0  9.647440e+08
# 110656        608      1.0   2.5  1.117408e+09
# 111487        609      1.0   3.0  8.472210e+08
# 111524        610      1.0   5.0  1.479543e+09
#
# [233 rows x 4 columns]

# %%
medias_por_filme = notas.groupby('filmeId')['nota'].mean()
medias_por_filme.head()
# Out:
# filmeId
# 1.0    3.903433
# 2.0    3.441667
# 3.0    3.210526
# 4.0    2.250000
# 5.0    3.038462
# Name: nota, dtype: float64

# %%
medias_por_filme.plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
sns.boxplot(medias_por_filme)
# Out:
# <Axes: ylabel='nota'>

# %%
medias_por_filme.describe()
# Out:
# count    9724.000000
# mean        3.255670
# std         0.872836
# min         0.500000
# 25%         2.777778
# 50%         3.400000
# 75%         3.904762
# max         5.000000
# Name: nota, dtype: float64

# %%
import matplotlib.pyplot as plt

sns.displot(medias_por_filme, kde=True)
plt.title('Histograma das medias dos filmes')
# Out:
# Text(0.5, 1.0, 'Histograma das medias dos filmes')

# %%
filmes = pd.read_csv("https://raw.githubusercontent.com/alura-cursos/data-science-analise-exploratoria/main/Aula_0/ml-latest-small/movies.csv")
filmes.columns = ["filmeId", "titulo", "generos"]
filmes.head()
# Out:
#    filmeId                              titulo  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                        generos
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
tmdb = pd.read_csv('/content/tmdb_5000_movies.csv')
tmdb.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-b76e9378a339> in <cell line: 1>()
# ----> 1 tmdb = pd.read_csv('/content/tmdb_5000_movies.csv')
#       2 tmdb.head()
#
# NameError: name 'pd' is not defined

# %%
sns.displot(tmdb['revenue'])
plt.title('Distribuicao das receitas dos filmes')
plt.show()

# %%
# prompt: grafico de distribuicao do orcamento dos filmes (budget)

sns.displot(tmdb['budget'])
plt.title('Distribuicao do orcamento dos filmes')
plt.show()

# %%
tmdb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4803 entries, 0 to 4802
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   budget                4803 non-null   int64
#  1   genres                4803 non-null   object
#  2   homepage              1712 non-null   object
#  3   id                    4803 non-null   int64
#  4   keywords              4803 non-null   object
#  5   original_language     4803 non-null   object
#  6   original_title        4803 non-null   object
#  7   overview              4800 non-null   object
#  8   popularity            4803 non-null   float64
#  9   production_companies  4803 non-null   object
#  10  production_countries  4803 non-null   object
#  11  release_date          4802 non-null   object
#  12  revenue               4803 non-null   int64
#  13  runtime               4801 non-null   float64
#  14  spoken_languages      4803 non-null   object
#  15  status                4803 non-null   object
#  16  tagline               3959 non-null   object
#  17  title                 4803 non-null   object
#  18  vote_average          4803 non-null   float64
#  19  vote_count            4803 non-null   int64
# dtypes: float64(3), int64(4), object(13)
# memory usage: 750.6+ KB

# %%
tmdb.describe()
# Out:
#              budget             id   popularity       revenue      runtime  \
# count  4.803000e+03    4803.000000  4803.000000  4.803000e+03  4801.000000
# mean   2.904504e+07   57165.484281    21.492301  8.226064e+07   106.875859
# std    4.072239e+07   88694.614033    31.816650  1.628571e+08    22.611935
# min    0.000000e+00       5.000000     0.000000  0.000000e+00     0.000000
# 25%    7.900000e+05    9014.500000     4.668070  0.000000e+00    94.000000
# 50%    1.500000e+07   14629.000000    12.921594  1.917000e+07   103.000000
# 75%    4.000000e+07   58610.500000    28.313505  9.291719e+07   118.000000
# max    3.800000e+08  459488.000000   875.581305  2.787965e+09   338.000000
#
#        vote_average    vote_count
# count   4803.000000   4803.000000
# mean       6.092172    690.217989
# std        1.194612   1234.585891
# min        0.000000      0.000000
# 25%        5.600000     54.000000
# 50%        6.200000    235.000000
# 75%        6.800000    737.000000
# max       10.000000  13752.000000

# %%
com_faturamento = tmdb.query('revenue > 0')
sns.displot(com_faturamento['revenue'])

# %%
tmdb['original_language'].unique()
# Out:
# array(['en', 'ja', 'fr', 'zh', 'es', 'de', 'hi', 'ru', 'ko', 'te', 'cn',
#        'it', 'nl', 'ta', 'sv', 'th', 'da', 'xx', 'hu', 'cs', 'pt', 'is',
#        'tr', 'nb', 'af', 'pl', 'he', 'ar', 'vi', 'ky', 'id', 'ro', 'fa',
#        'no', 'sl', 'ps', 'el'], dtype=object)

# %%
tmdb['original_language'].value_counts()
# Out:
# original_language
# en    4505
# fr      70
# es      32
# zh      27
# de      27
# hi      19
# ja      16
# it      14
# cn      12
# ru      11
# ko      11
# pt       9
# da       7
# sv       5
# nl       4
# fa       4
# th       3
# he       3
# ta       2
# cs       2
# ro       2
# id       2
# ar       2
# vi       1
# sl       1
# ps       1
# no       1
# ky       1
# hu       1
# pl       1
# af       1
# nb       1
# tr       1
# is       1
# xx       1
# te       1
# el       1
# Name: count, dtype: int64

# %%
tmdb['original_language'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-739d0c8a0328> in <cell line: 1>()
# ----> 1 tmdb['original_language'].value_counts().index()
#
# NameError: name 'tmdb' is not defined
